# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("exercicio-semana11/imagens/Fig1039(a)(polymersomes).png", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, 'gray')
plt.axis("off")
plt.show()
# Out:
# (648, 702)

# %%
esqCima = img[0:234,0:216].astype(np.uint8)
meioCima = img[0:234, 216:432].astype(np.uint8)
dirCima = img[0:234, 432:648].astype(np.uint8)
esqMeio = img[234:468,0:216].astype(np.uint8)
centro = img[234:468, 216:432].astype(np.uint8)
dirMeio = img[234:468, 432:648].astype(np.uint8)
esqBaixo = img[468:702,0:216].astype(np.uint8)
meioBaixo = img[468:702, 216:432].astype(np.uint8)
dirBaixo = img[468:702, 432:648].astype(np.uint8)

plt.imshow(esqCima ,'gray')
plt.axis("off")
plt.show()

# %%
listaNomes = ["esqCima", meioCima, dirCima, esqMeio, centro, dirMeio, esqBaixo, meioBaixo, dirBaixo]

for nome in listaNomes:
    print(nome)
    limiar, novo = cv2.threshold(nome,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    print(limiar)
    #plt.imshow(nome ,'gray')


plt.imshow(meioCima ,'gray')
plt.axis("off")

# %%
limiar1,saida1 = cv2.threshold(esqCima,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar2,saida2 = cv2.threshold(meioCima,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar3,saida3 = cv2.threshold(dirCima,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar4,saida4 = cv2.threshold(esqMeio,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar5,saida5 = cv2.threshold(centro,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar6,saida6 = cv2.threshold(dirMeio,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar7,saida7 = cv2.threshold(esqBaixo,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar8,saida8 = cv2.threshold(meioBaixo,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
limiar9,saida9 = cv2.threshold(dirBaixo,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

print(limiar1)
print(limiar2)
print(limiar3)
print(limiar4)
print(limiar5)
print(limiar6)
print(limiar7)
print(limiar8)
print(limiar9)

# plt.imshow(saida1 ,'gray')
# plt.axis("off")
# plt.imshow(saida2 ,'gray')
# plt.axis("off")
# plt.imshow(saida3 ,'gray')
# plt.axis("off")
# plt.imshow(saida4 ,'gray')
# plt.axis("off")
# plt.imshow(saida5 ,'gray')
# plt.axis("off")
# plt.imshow(saida6 ,'gray')
# plt.axis("off")
# plt.imshow(saida7 ,'gray')
# plt.axis("off")
# plt.imshow(saida8 ,'gray')
# plt.axis("off")
# plt.imshow(saida9 ,'gray')
# plt.axis("off")
# Out:
# 138.0
# 175.0
# 170.0
# 178.0
# 183.0
# 175.0
# 181.0
# 183.0
# 154.0

# %%
limiar,saida = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(saida ,'gray')
plt.axis("off")
# Out:
# (-0.5, 701.5, 647.5, -0.5)
