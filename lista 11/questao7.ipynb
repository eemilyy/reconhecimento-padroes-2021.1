# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("exercicio-semana11/imagens/Fig0334(a)(hubble-original).png", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, 'gray')
plt.axis("off")
plt.show()

# %% [markdown]
# (a) Aplique um ltro de média 15x15.

# %%
ksize = (15, 15)
image = cv2.blur(img, ksize) 

plt.imshow(image, 'gray')
plt.axis("off")
plt.show()
print(image.shape)
# Out:
# (528, 485)

# %%
t = 64
tNovo = t
delta = 3

image = image.astype(np.uint8)
# while True:
#     g1 = []
#     g2 = []
#     for i in range(image.shape[0]):
#         for j in range(image.shape[1]):
#             if img[i][j] > t:
#                 g1.append(image[i][j])
#             else:
#                 g2.append(image[i][j])

#     mediag1 = np.mean(g1)
#     mediag2 = np.mean(g2)

#     t = tNovo
#     tNovo = (mediag1 + mediag2) / 2

#     if (t - tNovo) < delta:
#         break

for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        if image [i][j] < 64:
            image[i][j] = 0
        else:
            image[i][j] = 255

plt.imshow(image, 'gray')
plt.axis("off")
plt.show()

# %%
image2 = image.astype(np.uint8)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        image[i][j] = int(image[i][j]) * int(img[i][j])


plt.imshow(image, 'gray')
plt.axis("off")
plt.show()
